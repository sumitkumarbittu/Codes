# %%
a = {4,3,6,1}

print(a)
# Out:
# {1, 3, 4, 6}

# %%
a.add(5)

print(a)
# Out:
# {1, 3, 4, 5, 6}

# %%
a.remove(4)

print(a)
# Out:
# {1, 3, 5, 6}

# %%
a.pop()

print(a)
# Out:
# {3, 5, 6}

# %%
b = {66, -4, 3}

a.union(b)
# Out:
# {-4, 3, 5, 6, 66}

# %%
a.intersection(b)
# Out:
# {3}

# %%
a.difference(b)
# Out:
# {5, 6}

# %%
print(a)

print(b)
# Out:
# {3, 5, 6}
# {66, 3, -4}

# %%
c = {5, 6}

c.issubset(a)
# Out:
# True

# %%
a.issuperset(c)
# Out:
# True

# %%
b.clear()

# %%
print(a)

print(b)
# Out:
# {3, 5, 6}
# set()
