# %%
t = (1,2,3,4,5,2,1,2,6,2)

print(t)
# Out:
# (1, 2, 3, 4, 5, 2, 1, 2, 6, 2)

# %%
print(t[3])

print(t.count(2))

print(t.index(6))
# Out:
# 4
# 4
# 8

# %%
tt = 10,11,12

a,b,c = tt

print(a,b)
# Out:
# 10 11

# %%
print(tt)
# Out:
# (10, 11, 12)

# %%
l = list(t)

print(l)
# Out:
# [1, 2, 3, 4, 5, 2, 1, 2, 6, 2]
