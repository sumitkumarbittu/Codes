# %%
l = [1,2,3]

print(l)
# Out:
# [1, 2, 3]

# %%
l.append(4)

print(l)
# Out:
# [1, 2, 3, 4]

# %%
l.extend([5,6])

print(l)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l.insert(2,10)

print(l)
# Out:
# [1, 2, 10, 3, 4, 5, 6]

# %%
l.remove(5)

print(l)
# Out:
# [1, 2, 10, 3, 4, 6]

# %%
l.pop(3)

print(l)
# Out:
# [1, 2, 10, 4, 6]

# %%
print(l.index(10))

print(l.count(10))
# Out:
# 2
# 1

# %%
l.sort()

print(l)
# Out:
# [1, 2, 4, 6, 10]

# %%
ll = l.copy()

print(ll)
# Out:
# [1, 2, 4, 6, 10]

# %%
l.reverse()

print(l)
# Out:
# [10, 6, 4, 2, 1]

# %%
l.clear()

print(l)
# Out:
# []

# %%
squares = [x**2 for x in range(5)]

print(squares)
# Out:
# [0, 1, 4, 9, 16]

# %%
even = [x for x in range(10) if x%2==0]

print(even)
# Out:
# [0, 2, 4, 6, 8]
